# %% [markdown]
# ###  LAB - S03 L006 Oczyszczanie danych - fillna()
#
# tu chyba wchodzi future warning:
#
# było:
#
#     df['col'].fillna(0,inplace=True)
#
# a jest:
#
#     df.fillna({'col':0},inplace = True)
#
#
# ###  LAB - S03-L012 - PDF
#
#
# - brak polecenia : index_col='VehicleID we wczytywaniu pliku,
# użytkownicy będą w swoich odpowiedziach mieli index generowany automatycznie,
# mogło się to powtórzyć w kilku lekcjach z wykorzystaniem fuel.csv
#
#
# ### LAB  S05 L007 - f.melt - PDF
#
# - brak polecenia zadania nr 10
# - przy poleceniu: nr 7,8,9 (ponowna zamiana na pivot table,usunięcie indexu i użycie f.melt) - daje błąd:
#
# *KeyError: "The following id_vars or value_vars are not present in the DataFrame: ['Age']"
# (skopiowałem z rozwiązań ale błąd ciągle wyskakuje)*
#
# ### LAB - S05-L003 - Swaplevel - PDF
#
# - plik pdf nazywa się S05-L004-LAB+Swaplevel.pdf, L003 nie pobrałem bo chyba go nie ma
#
# - brak rozwiązania zadania nr 2
#
#
# ### LAB  S05 L006 - pivot table
#
# - 1 polecenie  - literówka w kolumnie: Bip - Bib
#
# - brak odpowiedzi nr 8 w pdf:
#
# powinno być:
#
#     df.pivot_table(index='Age',values ='City',aggfunc='count')
#
# od razu jest następna odpowiedź z indexem 'Country':
#
#     df.pivot_table(index='Country',values ='City',aggfunc='count')
#
#
#
# ### LAB S08 L004  - pie plot - PDF
#
# - polecenie z bloku przygotowującego do ćwiczenia daje błąd
#
# *datetime64 type does not support sum operations*
#
# Wydaje się że polecenie chce zsumować wartości z kolumny "status_published".
#
# było:
#
#     nasa_by_month = nasa.groupby(by='month').sum()
#
# a powinno być:
#
#     nasa_by_month = nasa.groupby(by='month').sum(numeric_only=True)
#
# - w poleceniu zadania nr3 jest: uzyj "num_likes" a w odpowiedzi "num_comments"
#
#
#
# ### LAB S08-L005-LAB+Metoda+plot.pdf
#
#
# - brak 12 polecenia zadania(uciety pdf)
#
#
# ### LAB S08-L006 - Wykres scatter hexbin area
#
#
# - Wydaje się,że w oryginalnym df w kol. '40K' pojawiły się wartości których nie skonwertuje do liczby sekund przy pomocy
#
#
#
#
#
#         marathon["TimeSeconds"] = marathon["40K"].apply(lambda x: pd.Timedelta(x).total_seconds())
#
# komórki:
#
# 25940
# 17026
# 14688
# 16658
# 16590
# 25517
#
#
#
# miały czas zawodników którzy nie ukończyli biegu - czyli minus zamiast wartości liczbowych.
#
# *Błąd: valueerror: symbols w/o a number.*
#
# Jednakże! Udało mi się dzięki wiedzy zgromadzonej na kursie zlokazlizować problem,znaleźć problematyczne komórki:
#
# marathon['40K'].sort_values().head(10)
#
# i podmienić ich zawartość na fikcyjną:
#
# marathon.loc[14688,'40K'] = '2:18:13' ...itd z innymi.
#
#
# - Polecenie 2: jest Wyświetl wykres punktowy ... (kolumnaTotalSeconds)
# a miało chyba być:...(kolumna TimeSeconds) - ta nowo dodana kolumna.
#
# - Polecenie 6: skopiuj poniższy kod do sporządzenia wykresów (mr bean i nasa):
#
# *Future warning : TypeError: datetime64 type does not support sum operations*
#
# Dalsza część zadania niewykonalna,ze względu na brak argumentu numeric_only=True w funkcji sum(),
#
# brakuje też poleceń co do tej części,bo odpowiedzi są.
# W odpowiedziach pojawia się metoda append,którą trzeba zamienić na concat(wg erraty którą zamieściłeś w kursie)
#
#
# ### LAB - S10-L001 - Import
#
# - polecenie 8:  "zdropować" kolumnę  "indic_is,ind_type,unit,time\geo" w obiekcie df_desc a nie w  oryginalnym df.(odpowiedź dropuje w df )
#
# ### LAB - S10-L002 - export
#
# - 3 polecenie, plik mc-4.csv, brakuje polecenia: dodaj średnik jako separator
#
# ### LAB - S10-L003 - excel
#
# - pol.7 chodziło chyba o ten sam obiekt imported1 a nie nowy imported - odpowiedzi na to wskazują
#
#
# ### dziękuję za podzielenie się wiedzą, poczucie,że coś się udaje i można znaleźć błąd jest bezcenne!
